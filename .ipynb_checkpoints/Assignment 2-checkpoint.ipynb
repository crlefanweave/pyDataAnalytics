# %%
'''Author: Cody LeFan-Weaver
Assignment 2 CS321'''

import numpy as np
import csv
import random
import matplotlib.pyplot as plt
from collections import Counter

grads = []
counter = 0
mean = 0
median = 0
minGPA = 0
maxGPA = 0
q1 = 0
q3 = 0
stdv = 0
outliers = []
scienceMajors = 0
artMajors = 0
civicsMajors = 0
psychMajors = 0

'''preProcessing is something I am doing to fill in blank information for
students in the fields of county, honors, and gpa (which is something I made up).
This eliminates all empty fields. The data for each student is ultimately stored as an array 
of maps, which is held within an array. The structure is a two-dimensional array.'''
def preProcessing():
    global grads
    with open('grads.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        list = []
        for row in reader:
            if (row['Honors'] == ''):
                row['Honors'] = 'None'
                setGPA(row)
            else:
                row['GPA'] = 4.00
            if (row['Indiana County'] == ''):
                row['Indiana County'] = 'None'
            if (row['State'] == ''):
                row['State'] = 'FOREIGN'
            list.append(row)
    grads = list
                
            
                
def setGPA(stud):
    x = round(random.normalvariate(3.00, 0.33), 2)
    if (x > 3.99):
        x = 3.99
    stud['GPA'] = x

'''The main function will call on other functions to execute the program.'''
def part2():
    global grads

    findMinMax(grads)
    count(grads)
    meanMedian(grads)
    quartiles(grads)
    standDev(grads)
    findOutliers(grads)
    
def generateList():
    with open('grads.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        list = []
        for row in reader:
            list.append(row)
    return list

'''Beginning here are the functions to print the values we want from the data. This will be qualitative
data focused around the GPA that we have generated.'''
def findMinMax(list):
    global minGPA
    global maxGPA
    n = []
    for x in list:
        n.append(x['GPA'])
    minGPA = np.min(n)
    maxGPA = np.max(n)
    print("The min GPA is: %(min)f, the max GPA is:  %(max)f" % {'min':minGPA, 'max':maxGPA})

def count(list):
    global counter
    for x in list:
        counter+=1
    print("The number of graduate students is %(num)d" % {'num':counter})
    
def meanMedian(list):
    n = []
    global mean
    global median
    for x in list:
        n.append(x['GPA'])
    mean = round(np.mean(n), 2)
    median = round(np.median(n), 2)
    print("The mean GPA of graduates is %(num)f" % {'num':mean})
    print("The median GPA of graduates is %(num)f" % {'num':median})
    
def quartiles(list):
    n = []
    global q1
    global q3
    global counter
    for x in list:
        n.append(x['GPA'])
    n.sort()
    if (counter%4==0):
        q1 = n[counter//4]
        q3 = n[3*counter//4]
    else:
        q1 = (n[int(np.floor(counter/4))] + n[int(np.ceil(3*counter/4))])/2
        q3 = (n[int(np.floor(3*counter/4))] + n[int(np.ceil(3*counter/4))])/2
    print("Q1 is %(num)f" % {'num':q1})
    print("Q3 is %(num)f" % {'num':q3})
    
def standDev(list):
    n = []
    global stdv
    for x in list:
        n.append(x['GPA'])
    stdv = np.std(n)
    print("The standard deviation for this dataset is: %(num)f" % {'num':stdv})
    
def findOutliers(list):
    global mean
    global stdv
    global outliers
    print("The following are outliers in the dataset for GPA: ")
    for x in list:
        if ((x['GPA'] > mean+3*stdv) or (x['GPA'] < mean-3*stdv)):
            outliers.append(x)
            print(x['GPA'])

'''Beginning here will be the functions for part 3, in which I will examine
the number of students graduating from arts and sciences as compared to the total number of students.'''

def findDegreeType():
    global grads
    global counter
    global scienceMajors
    global artMajors
    global civicsMajors
    global psychMajors
    for x in grads:
        if 'SCIENCE' in x['Degree']:
            scienceMajors+=1
        elif 'ART' in x['Degree']:
            artMajors+=1
        elif 'MUS' in x['Degree']:
            artMajors+=1
        elif 'URB' in x['Degree']:
            civicsMajors+=1
        elif 'ARCH' in x['Degree']:
            civicsMajors+=1
        elif 'SOCIAL' in x['Degree']:
            psychMajors+=1
        elif 'PSYC' in x['Degree']:
            psychMajors+=1
        else:
            print(x)

'''This will output the percentage of all students who graduated with a degree in science or arts.'''
def outputDegreeStats():
    global counter
    global scienceMajors
    global artMajors
    global civicsMajors
    global psychMajors
    print("There are %(s)d science majors and %(a)d art majors." % {'s':scienceMajors, 'a':artMajors})
    print("There are %(c)d civics majors and %(p)d psych majors." % {'c':civicsMajors, 'p':psychMajors})
    print("Science majors make up %(num)f percent of all graduates." % {'num':100*scienceMajors/counter})
    print("Art majors make up %(num)f percent of all graduates." % {'num':100*artMajors/counter})

'''This creates a pie chart to show the relationship between the different types of degrees
that students graduate from Ball State with.'''
def visualizeDegreeStats():
    global scienceMajors
    global artMajors
    global civicsMajors
    global psychMajors
    x = [scienceMajors, artMajors, civicsMajors, psychMajors]
    
    plt.pie(x, explode=None, labels=['Science', 'Art', 'Civics', 'Psychology'],
    colors=('b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'),
    autopct=None, pctdistance=0.6, shadow=False,
    labeldistance=1.1, startangle=None, radius=None,
    counterclock=True, wedgeprops=None, textprops=None,
    center = (0, 0), frame = False )
    plt.show()

'''Shows a histogram to visualize the spread of GPAs among those who graduate from Ball State.'''
def visualizeGPASpread():
    global grads
    gpa = []
    for x in grads:
        gpa.append(x['GPA'])
    
    plt.hist(gpa)
    plt.show()
    
'''This will help to visualize the number of students who graduate from Ball State based on
where they have come from and live.'''
def visualizeHome():
    global grads
    loc = []
    data = []
    for x in grads:
        if (x['State'] == 'INDIANA'):
            loc.append('Indiana')
        elif (x['State'] == 'FOREIGN'):
            loc.append('Other Country')
        else:
            loc.append('Other State')
    labSet = set(loc)
    lab = list(labSet)
    count = Counter(loc)
    
    plt.pie(list(count.values()), explode=None, labels=lab,
    colors=('b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'),
    autopct=None, pctdistance=0.6, shadow=False,
    labeldistance=1.1, startangle=None, radius=None,
    counterclock=True, wedgeprops=None, textprops=None,
    center = (0, 0), frame = False )
    plt.show()

# %%
preProcessing()

# %%
part2()
# Out:
# The min GPA is: 1.920000, the max GPA is:  4.000000
# The number of graduate students is 2492
# The mean GPA of graduates is 3.200000
# The median GPA of graduates is 3.110000
# Q1 is 2.830000
# Q3 is 3.510000
# The standard deviation for this dataset is: 0.501337
# The following are outliers in the dataset for GPA:

# %%
findDegreeType()
outputDegreeStats()
# Out:
# {'Indiana County': 'Randolph', 'State': 'INDIANA', 'Student Name': 'Alexandra Crabtree', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.83, 'City': 'Parker City', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'OHIO', 'Student Name': 'Jewell Crawford', 'Degree': 'DOCTORATE IN NURSING PRACT', 'GPA': 3.27, 'City': 'Brookville', 'Honors': 'None'}
# {'Indiana County': 'Madison', 'State': 'INDIANA', 'Student Name': 'Brittany Cripe', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.49, 'City': 'Anderson', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'FOREIGN', 'Student Name': 'Athena Maniya Dacanay', 'Degree': 'PH.D', 'GPA': 2.58, 'City': '', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Jonathon Dages', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.2, 'City': 'Westfield', 'Honors': 'None'}
# {'Indiana County': 'Porter', 'State': 'INDIANA', 'Student Name': 'Brittany Doll', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.11, 'City': 'Portage', 'Honors': 'None'}
# {'Indiana County': 'Grant', 'State': 'INDIANA', 'Student Name': 'Nicholas Duke', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.54, 'City': 'Marion', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Alan Dumond', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.97, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Boone', 'State': 'INDIANA', 'Student Name': 'Ashley Dye', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.64, 'City': 'Whitestown', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'TEXAS', 'Student Name': 'Funmilayo Edunjobi-Aina', 'Degree': 'DOCTORATE IN NURSING PRACT', 'GPA': 3.0, 'City': 'Richmond', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Julianne Edwards', 'Degree': 'PH.D', 'GPA': 3.11, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Daniel Elias', 'Degree': 'PH.D', 'GPA': 2.79, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Tippecanoe', 'State': 'INDIANA', 'Student Name': 'Katelynn Emmert-Perigo', 'Degree': 'DOCTOR OF AUDIOLOGY', 'GPA': 3.01, 'City': 'Lafayette', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Kenneth Estep', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.32, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Christina Fackler', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.73, 'City': 'Carmel', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Khalid Fazly', 'Degree': 'MASTER OF PUBLIC ADMINIST.', 'GPA': 2.98, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Allen', 'State': 'INDIANA', 'Student Name': 'Nick Feipel', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.28, 'City': 'Fort Wayne', 'Honors': 'None'}
# {'Indiana County': 'Marshall', 'State': 'INDIANA', 'Student Name': 'Laura Ferrari', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.83, 'City': 'Culver', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'FLORIDA', 'Student Name': 'Amy Fritz-Ocock', 'Degree': 'DOCTOR OF EDUCATION', 'GPA': 3.24, 'City': 'Winter Garden', 'Honors': 'None'}
# {'Indiana County': 'Cass', 'State': 'INDIANA', 'Student Name': 'Shelby Fry', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.33, 'City': 'Walton', 'Honors': 'None'}
# {'Indiana County': 'La Porte', 'State': 'INDIANA', 'Student Name': 'Joan Furore', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.11, 'City': 'Michigan City', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'ILLINOIS', 'Student Name': 'Edward Garard', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.77, 'City': 'Northfield', 'Honors': 'None'}
# {'Indiana County': 'Monroe', 'State': 'INDIANA', 'Student Name': 'Timothy Gholson', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.63, 'City': 'Bloomington', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Zakeita Gilmore', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.4, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Henry', 'State': 'INDIANA', 'Student Name': 'Gus Goggin', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.96, 'City': 'Cambridge City', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'NEVADA', 'Student Name': 'Cameron Gonzales', 'Degree': 'DOCTOR OF EDUCATION', 'GPA': 2.96, 'City': 'North Las Vegas', 'Honors': 'None'}
# {'Indiana County': 'Hendricks', 'State': 'INDIANA', 'Student Name': 'Dominique Granger', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.89, 'City': 'Plainfield', 'Honors': 'None'}
# {'Indiana County': 'Benton', 'State': 'INDIANA', 'Student Name': 'Jacob Gretencord', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.19, 'City': 'Oxford', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'NEW YORK', 'Student Name': 'Stephanie Hagquist', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.19, 'City': 'Tuckahoe', 'Honors': 'None'}
# {'Indiana County': 'Johnson', 'State': 'INDIANA', 'Student Name': 'Jessica Harl', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.72, 'City': 'Greenwood', 'Honors': 'None'}
# {'Indiana County': 'Fulton', 'State': 'INDIANA', 'Student Name': 'Jeremiah Harvey', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.78, 'City': 'Rochester', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Charlotte Hawkins', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.93, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Austin Heffner', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.38, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Bartholomew', 'State': 'INDIANA', 'Student Name': 'Teresa Heiny', 'Degree': 'SPECIALIST IN EDUCATION', 'GPA': 2.98, 'City': 'Columbus', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Valerie M. Hennessy Hennessy', 'Degree': 'DOCTOR OF AUDIOLOGY', 'GPA': 2.57, 'City': 'Fishers', 'Honors': 'None'}
# {'Indiana County': 'Elkhart', 'State': 'INDIANA', 'Student Name': 'Sarah Herr', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.12, 'City': 'Elkhart', 'Honors': 'None'}
# {'Indiana County': 'Marion', 'State': 'INDIANA', 'Student Name': 'Angela Hetrick', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.88, 'City': 'Indianapolis', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'ILLINOIS', 'Student Name': 'Adam Babiarz', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 3.01, 'City': 'Elmwood Park', 'Honors': 'None'}
# {'Indiana County': 'Whitley', 'State': 'INDIANA', 'Student Name': 'Nicki Baker', 'Degree': 'PH.D', 'GPA': 3.35, 'City': 'Columbia City', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Austin High', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.47, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Sarah Highsmith', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.23, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Josh Holloway', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.52, 'City': 'Noblesville', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'OHIO', 'Student Name': 'Duncan Homan', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.37, 'City': 'Saint Henry', 'Honors': 'None'}
# {'Indiana County': 'Marion', 'State': 'INDIANA', 'Student Name': 'Jennifer Hoopingarner', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 2.92, 'City': 'Indianapolis', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'ILLINOIS', 'Student Name': 'Kevin Horgan', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.78, 'City': 'Wheaton', 'Honors': 'None'}
# {'Indiana County': 'Howard', 'State': 'INDIANA', 'Student Name': 'Adelle Howell', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.51, 'City': 'Greentown', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'ONTARIO', 'Student Name': 'Delaney Howson', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.4, 'City': 'Barrie', 'Honors': 'None'}
# {'Indiana County': 'Marion', 'State': 'INDIANA', 'Student Name': 'Jeffrey Hunnicutt', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.61, 'City': 'Indianapolis', 'Honors': 'None'}
# {'Indiana County': 'Allen', 'State': 'INDIANA', 'Student Name': 'Erin Hunter', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 2.84, 'City': 'Monroeville', 'Honors': 'None'}
# {'Indiana County': 'Wayne', 'State': 'INDIANA', 'Student Name': 'Michael Ingram', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 2.77, 'City': 'Richmond', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Seth Ireland', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 2.78, 'City': 'Arcadia', 'Honors': 'None'}
# {'Indiana County': 'Putnam', 'State': 'INDIANA', 'Student Name': 'Andrew Janik', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.11, 'City': 'Coatesville', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'OHIO', 'Student Name': 'Ashley Jones', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.41, 'City': 'Sidney', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Chantelle Jones', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.52, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'VIRGINIA', 'Student Name': 'Herman Jones', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.53, 'City': 'North Chesterfield', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Clint Kearney', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.63, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Marion', 'State': 'INDIANA', 'Student Name': 'Abbie Klingsmith', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 2.76, 'City': 'Indianapolis', 'Honors': 'None'}
# {'Indiana County': 'Elkhart', 'State': 'INDIANA', 'Student Name': 'Sarah Kniesly', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.83, 'City': 'Goshen', 'Honors': 'None'}
# {'Indiana County': 'Marion', 'State': 'INDIANA', 'Student Name': 'Patrick Kuhn', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.62, 'City': 'Indianapolis', 'Honors': 'None'}
# {'Indiana County': 'Porter', 'State': 'INDIANA', 'Student Name': 'Julie Lauck', 'Degree': 'DOCTOR OF EDUCATION', 'GPA': 2.87, 'City': 'Valparaiso', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Mei Li', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 2.67, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'White', 'State': 'INDIANA', 'Student Name': 'Sam Luzadder', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.82, 'City': 'Monticello', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'ILLINOIS', 'Student Name': 'Kimberly Lynch', 'Degree': 'DOCTORATE IN NURSING PRACT', 'GPA': 2.91, 'City': 'Libertyville', 'Honors': 'None'}
# {'Indiana County': 'Brown', 'State': 'INDIANA', 'Student Name': 'Mark Madden', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.06, 'City': 'Nashville', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Samone Marshall', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.04, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Grant', 'State': 'INDIANA', 'Student Name': 'Karen Marvel', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.35, 'City': 'Fairmount', 'Honors': 'None'}
# {'Indiana County': 'St Joseph', 'State': 'INDIANA', 'Student Name': 'Jennifer Bastock', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.65, 'City': 'Mishawaka', 'Honors': 'None'}
# {'Indiana County': 'Allen', 'State': 'INDIANA', 'Student Name': 'Andrea Bearden', 'Degree': 'DOCTORATE IN NURSING PRACT', 'GPA': 2.53, 'City': 'Woodburn', 'Honors': 'None'}
# {'Indiana County': 'Rush', 'State': 'INDIANA', 'Student Name': 'Rachel Beavers', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.0, 'City': 'Rushville', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Derek Berger', 'Degree': 'DOCTOR OF EDUCATION', 'GPA': 2.49, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Hendricks', 'State': 'INDIANA', 'Student Name': 'Mark Melton', 'Degree': 'SPECIALIST IN EDUCATION', 'GPA': 3.08, 'City': 'Pittsboro', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Robert Miles', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.9, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Reese Miller', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.64, 'City': 'Carmel', 'Honors': 'None'}
# {'Indiana County': 'Allen', 'State': 'INDIANA', 'Student Name': 'Tia Miller', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 2.77, 'City': 'Fort Wayne', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'ILLINOIS', 'Student Name': 'Daniel Misbach', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.41, 'City': 'Chicago', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Himank Mishra', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.32, 'City': 'Fishers', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Jenny Mitchell', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.63, 'City': 'Carmel', 'Honors': 'None'}
# {'Indiana County': 'Fulton', 'State': 'INDIANA', 'Student Name': 'Lauren Mitchell', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.55, 'City': 'Rochester', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'ILLINOIS', 'Student Name': 'Elhaum Mogharreban', 'Degree': 'DOCTOR OF AUDIOLOGY', 'GPA': 3.2, 'City': 'Carbondale', 'Honors': 'None'}
# {'Indiana County': 'Boone', 'State': 'INDIANA', 'Student Name': 'Bethany Moore', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.81, 'City': 'Lebanon', 'Honors': 'None'}
# {'Indiana County': 'Wayne', 'State': 'INDIANA', 'Student Name': 'Kari Morrison', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.78, 'City': 'Richmond', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Taylor Mullins', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.98, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Michael Nauman', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.05, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Marion', 'State': 'INDIANA', 'Student Name': 'Brooke Owens', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.73, 'City': 'Indianapolis', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Erika Owens', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 3.07, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Allen', 'State': 'INDIANA', 'Student Name': 'Casey Parris', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 2.74, 'City': 'Fort Wayne', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'FLORIDA', 'Student Name': 'Julia Patton', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.15, 'City': 'Winter Garden', 'Honors': 'None'}
# {'Indiana County': 'Jackson', 'State': 'INDIANA', 'Student Name': 'Cameron Personett', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.11, 'City': 'Seymour', 'Honors': 'None'}
# {'Indiana County': 'Monroe', 'State': 'INDIANA', 'Student Name': 'David Pillar', 'Degree': 'DOCTOR OF EDUCATION', 'GPA': 3.2, 'City': 'Bloomington', 'Honors': 'None'}
# {'Indiana County': 'St Joseph', 'State': 'INDIANA', 'Student Name': 'Michael Podell', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.14, 'City': 'South Bend', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Aniketh Ramname', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.17, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Grant', 'State': 'INDIANA', 'Student Name': 'Manuel Rangel', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.98, 'City': 'Marion', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'TEXAS', 'Student Name': 'Dane Regnier', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.23, 'City': 'Austin', 'Honors': 'None'}
# {'Indiana County': 'Shelby', 'State': 'INDIANA', 'Student Name': 'Jeanie Reuter', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.27, 'City': 'Morristown', 'Honors': 'None'}
# {'Indiana County': 'Elkhart', 'State': 'INDIANA', 'Student Name': 'Michael Romano', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 2.67, 'City': 'Bristol', 'Honors': 'None'}
# {'Indiana County': 'Floyd', 'State': 'INDIANA', 'Student Name': 'Jason Roseberry', 'Degree': 'DOCTOR OF EDUCATION', 'GPA': 2.75, 'City': 'New Albany', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Amanda Rosinko', 'Degree': 'DOCTOR OF AUDIOLOGY', 'GPA': 2.71, 'City': 'Carmel', 'Honors': 'None'}
# {'Indiana County': 'Hancock', 'State': 'INDIANA', 'Student Name': 'Trey Ross', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.02, 'City': 'Mc Cordsville', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Elisha Schlabach', 'Degree': 'SPECIALIST IN EDUCATION', 'GPA': 2.62, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Erin Schlick', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.97, 'City': 'Noblesville', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'OHIO', 'Student Name': 'Gabriel Schuh', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 2.97, 'City': 'Greenville', 'Honors': 'None'}
# {'Indiana County': 'Johnson', 'State': 'INDIANA', 'Student Name': 'Anthony Scott', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 4.0, 'City': 'Franklin', 'Honors': 'Cum Laude'}
# {'Indiana County': 'None', 'State': 'FOREIGN', 'Student Name': 'Stacy Seibold', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.56, 'City': '', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'ILLINOIS', 'Student Name': 'Maulik Shah', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.09, 'City': 'Chicago', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'MICHIGAN', 'Student Name': 'Brian Berry', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.06, 'City': 'Okemos', 'Honors': 'None'}
# {'Indiana County': 'Kosciusko', 'State': 'INDIANA', 'Student Name': 'Megan Bibler', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 3.43, 'City': 'Claypool', 'Honors': 'None'}
# {'Indiana County': 'Fayette', 'State': 'INDIANA', 'Student Name': 'Lindsey Blakley', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.06, 'City': 'Connersville', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Todd Blevins', 'Degree': 'MASTER OF PUBLIC ADMINIST.', 'GPA': 2.45, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Dubois', 'State': 'INDIANA', 'Student Name': 'Aubree Block', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 2.36, 'City': 'Jasper', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'ILLINOIS', 'Student Name': 'Kaleigh Sheahan', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.05, 'City': 'DeKalb', 'Honors': 'None'}
# {'Indiana County': 'Wayne', 'State': 'INDIANA', 'Student Name': 'Garrett Shook', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 3.46, 'City': 'Hagerstown', 'Honors': 'None'}
# {'Indiana County': 'Henry', 'State': 'INDIANA', 'Student Name': 'Jennifer Shue', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.66, 'City': 'New Castle', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Stephanie Simopoulos', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 2.76, 'City': 'Noblesville', 'Honors': 'None'}
# {'Indiana County': 'Grant', 'State': 'INDIANA', 'Student Name': 'Jennifer Smith', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.03, 'City': 'Marion', 'Honors': 'None'}
# {'Indiana County': 'Lake', 'State': 'INDIANA', 'Student Name': 'Natalie Spork', 'Degree': 'DOCTOR OF AUDIOLOGY', 'GPA': 2.89, 'City': 'Crown Point', 'Honors': 'None'}
# {'Indiana County': 'Rush', 'State': 'INDIANA', 'Student Name': 'Terry Stiers', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.84, 'City': 'Rushville', 'Honors': 'None'}
# {'Indiana County': 'Lake', 'State': 'INDIANA', 'Student Name': 'Aaron Strombeck', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.13, 'City': 'Highland', 'Honors': 'None'}
# {'Indiana County': 'Allen', 'State': 'INDIANA', 'Student Name': 'Wanietta Stuckey', 'Degree': 'DOCTOR OF EDUCATION', 'GPA': 2.42, 'City': 'Spencerville', 'Honors': 'None'}
# {'Indiana County': 'Noble', 'State': 'INDIANA', 'Student Name': 'Stephanie Swank', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 3.06, 'City': 'Ligonier', 'Honors': 'None'}
# {'Indiana County': 'Boone', 'State': 'INDIANA', 'Student Name': 'Christopher Torrance', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.99, 'City': 'Zionsville', 'Honors': 'None'}
# {'Indiana County': 'Lagrange', 'State': 'INDIANA', 'Student Name': 'Rebecca Troyer', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.6, 'City': 'Topeka', 'Honors': 'None'}
# {'Indiana County': 'Bartholomew', 'State': 'INDIANA', 'Student Name': 'Andrea Valentine', 'Degree': 'DOCTORATE IN NURSING PRACT', 'GPA': 2.48, 'City': 'Columbus', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Jenna Waiz', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.74, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Marion', 'State': 'INDIANA', 'Student Name': 'Megan Walter', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.95, 'City': 'Indianapolis', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Danielle Watkins', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.87, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'LaMont Webb', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.83, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Chad Wells', 'Degree': 'MASTER OF PUBLIC ADMINIST.', 'GPA': 2.44, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'Dearborn', 'State': 'INDIANA', 'Student Name': 'Courtney White', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 2.8, 'City': 'Guilford', 'Honors': 'None'}
# {'Indiana County': 'Kosciusko', 'State': 'INDIANA', 'Student Name': 'Thayne White', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.08, 'City': 'Leesburg', 'Honors': 'None'}
# {'Indiana County': 'St Joseph', 'State': 'INDIANA', 'Student Name': 'Matt Williams', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.63, 'City': 'Granger', 'Honors': 'None'}
# {'Indiana County': 'Shelby', 'State': 'INDIANA', 'Student Name': 'Joseph Williamson', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.23, 'City': 'Boggstown', 'Honors': 'None'}
# {'Indiana County': 'Hancock', 'State': 'INDIANA', 'Student Name': 'Alyson Wood', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 4.0, 'City': 'Greenfield', 'Honors': 'Summa Cum Laude'}
# {'Indiana County': 'Madison', 'State': 'INDIANA', 'Student Name': 'Mitch Yeagy', 'Degree': 'BACHELOR OF ATHLETIC TRAINING', 'GPA': 4.0, 'City': 'Alexandria', 'Honors': 'Cum Laude'}
# {'Indiana County': 'None', 'State': 'OHIO', 'Student Name': 'Kylie Young', 'Degree': 'DOCTOR OF AUDIOLOGY', 'GPA': 3.26, 'City': 'Ansonia', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Jeanette Bousman', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 4.0, 'City': 'Muncie', 'Honors': 'Cum Laude'}
# {'Indiana County': 'Allen', 'State': 'INDIANA', 'Student Name': 'Lavon Brewer', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.21, 'City': 'Fort Wayne', 'Honors': 'None'}
# {'Indiana County': 'Lake', 'State': 'INDIANA', 'Student Name': 'Emily Brock', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.07, 'City': 'Dyer', 'Honors': 'None'}
# {'Indiana County': 'Johnson', 'State': 'INDIANA', 'Student Name': 'Avery Brown', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 3.05, 'City': 'Whiteland', 'Honors': 'None'}
# {'Indiana County': 'Hancock', 'State': 'INDIANA', 'Student Name': 'Jenna Brunton', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 2.98, 'City': 'New Palestine', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'MASSACHUSETTS', 'Student Name': 'Elisabeth Buck', 'Degree': 'PH.D', 'GPA': 2.88, 'City': 'New Bedford', 'Honors': 'None'}
# {'Indiana County': 'St Joseph', 'State': 'INDIANA', 'Student Name': 'Kyran Calhoun', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.21, 'City': 'South Bend', 'Honors': 'None'}
# {'Indiana County': 'Lake', 'State': 'INDIANA', 'Student Name': 'Nathan Castle', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.71, 'City': 'Lowell', 'Honors': 'None'}
# {'Indiana County': 'Hamilton', 'State': 'INDIANA', 'Student Name': 'Eric Clem', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.86, 'City': 'Noblesville', 'Honors': 'None'}
# {'Indiana County': 'Clinton', 'State': 'INDIANA', 'Student Name': 'Shae Commings', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.79, 'City': 'Frankfort', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Alexandra Anderson', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 2.68, 'City': 'Muncie', 'Honors': 'None'}
# {'Indiana County': 'St Joseph', 'State': 'INDIANA', 'Student Name': 'Evan Andreae', 'Degree': 'BACHELOR OF GENERAL STUDIES', 'GPA': 3.78, 'City': 'Granger', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'KENTUCKY', 'Student Name': 'Kaila Andrlik', 'Degree': 'DOCTOR OF AUDIOLOGY', 'GPA': 2.98, 'City': 'Nicholasville', 'Honors': 'None'}
# {'Indiana County': 'None', 'State': 'FOREIGN', 'Student Name': 'Fahad Aseery', 'Degree': 'DOCTOR OF EDUCATION', 'GPA': 3.22, 'City': '', 'Honors': 'None'}
# {'Indiana County': 'Delaware', 'State': 'INDIANA', 'Student Name': 'Salonee Athavale', 'Degree': 'MASTER OF BUSINESS ADMIN.', 'GPA': 2.61, 'City': 'Muncie', 'Honors': 'None'}
# There are 1425 science majors and 826 art majors.
# There are 55 civics majors and 37 psych majors.
# Science majors make up 57.182986 percent of all graduates.
# Art majors make up 33.146067 percent of all graduates.

# %%
visualizeDegreeStats()

# %%
visualizeGPASpread()

# %%
visualizeHome()
# Out:
# Counter({'Indiana': 1966, 'Other State': 500, 'Other Country': 26})
